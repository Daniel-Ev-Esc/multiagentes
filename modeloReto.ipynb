# %%
import agentpy as ap
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import IPython

# %% [markdown]
# - Movimiento
# - Recorrido
# - Detenerse con obstáculo
# - Respetar semáforo

# %%
class Carro(ap.Agent):
    def setup(self):
        
        #def __init__(self, grid, uniqueid, direction, rotation):
        self.grid = self.model.grid
        self.random = self.model.random
        self.group = 1
        #self.direction = direction
        #self.rotation = rotation
        
        # Posición inicial y cantidad de movimiento
        #arriba = (self.pos[0]-1, self.pos[1])
        #abajo = (self.pos[0]+1, self.pos[1])
        #izquierda = (self.pos[0], self.pos[1]-1)
        #derecha = (self.pos[0], self.pos[1]+1)
        self.stepAct = 0
        self.x = 0
        self.y = 10
        self.xstep = 1
        self.ystep = 1
        self.objX = 0
        self.objY = 15

    def printIni(self):
        print(self.x)
        print(self.y)

    def movexder(self):
        self.x += self.xstep
        self.grid.move_to(self, (self.y,self.x))
        self.stepAct += 1

    def movexizq(self):
        self.x -= self.xstep
        self.grid.move_to(self, (self.y,self.x))
        self.stepAct += 1

    def moveyarr(self):
        self.y -= self.ystep
        self.grid.move_to(self, (self.y,self.x))
        self.stepAct += 1
    
    def moveyab(self):
        self.y += self.ystep
        self.grid.move_to(self, (self.y,self.x))
        self.stepAct += 1

# %%
class CarModel(ap.Model):
    
    def setup(self):
        s = self.p.size
        n = 2

        self.grid = ap.Grid(self,(s,s), track_empty=True)
        self.agents = ap.AgentList(self,n,Carro)

        xini = [0,0]
        yini = [20,22]
        
        for i in range(0,2):
            self.agents[i].x = xini[i]
            self.agents[i].y = yini[i]
            self.agents[i].printIni()

        self.grid.add_agents(self.agents,[(yini[0],xini[0]),(yini[1],xini[1])],empty=True)

    def update(self):
        
        self.x = self.agents[0].x
        self.y = self.agents[0].y

        if  self.x == self.agents[0].objX and self.y == self.agents[0].objY:
            self.stop()

    def step(self):
        
        self.pasoAct = self.agents[0].stepAct

        if self.pasoAct < 20:
            self.agents.movexder()
        elif self.pasoAct < 25:
            self.agents.moveyarr()
        else:
            self.agents.movexizq()


    def get_movement(self):
        return [self.x, self.y]

    def end(self):
        self.report('movement',self.get_movement())

# %%
parameters = {
    'size' : 40,
    'steps' : 100,
    'n_groups': 2
}

# %%
def animation_plot(model, ax):
    ap.gridplot(model.grid.attr_grid('group'), cmap='Accent', ax=ax)
    ax.set_title(f"Car Model \n Time-step: {model.t}, "
                 f"Car: {model.get_movement()}")

fig, ax = plt.subplots()
model = CarModel(parameters)
animation = ap.animate(model, fig, ax, animation_plot)
IPython.display.HTML(animation.to_jshtml())
# Out:
# 0
# 20
# 0
# 22
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
# ...
